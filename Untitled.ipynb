# %%
import chromadb

client = chromadb.Client()
collection = client.create_collection(name = "my_collection")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File C:\Python311\Lib\site-packages\chromadb\utils\embedding_functions\onnx_mini_lm_l6_v2.py:63, in ONNXMiniLM_L6_V2.__init__(self, preferred_providers)
#      61 try:
#      62     # Equivalent to import onnxruntime
# ---> 63     self.ort = importlib.import_module("onnxruntime")
#      64 except ImportError:
#
# File C:\Python311\Lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1206, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1178, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1149, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:690, in _load_unlocked(spec)
#
# ...
